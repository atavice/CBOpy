# %%
from cbx.dynamics import CBO

f = lambda x: x[0] ** 2 + x[1] ** 2
dyn = CBO(f, d=2)
x = dyn.optimize()
# Out:
# ....................
# Starting Optimization with dynamic: CBO
# ....................
# Time: 0.010, best current energy: [0.0117932]
# Number of function evaluations: [40]
# Time: 0.020, best current energy: [0.00254253]
# Number of function evaluations: [60]
# Time: 0.030, best current energy: [0.00825151]
# Number of function evaluations: [80]
# Time: 0.040, best current energy: [0.00758471]
# Number of function evaluations: [100]
# Time: 0.050, best current energy: [0.00302336]
# Number of function evaluations: [120]
# Time: 0.060, best current energy: [0.00787164]
# Number of function evaluations: [140]
# Time: 0.070, best current energy: [0.00067621]
# Number of function evaluations: [160]
# Time: 0.080, best current energy: [0.00242343]
# Number of function evaluations: [180]
# Time: 0.090, best current energy: [0.00126499]
# Number of function evaluations: [200]
# Time: 0.100, best current energy: [0.00259449]
# Number of function evaluations: [220]
# ...
